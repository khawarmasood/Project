# %%
import pandas as pd
from google.colab import files
import numpy as np
import seaborn as sns; sns.set(color_codes=True)
from mpl_toolkits.mplot3d import Axes3D
# import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
uploaded = files.upload()

df = pd.read_csv("Food Price.csv")

df.head(10)
# Out:
#      <input type="file" id="files-e732c227-c8f3-44fd-8d80-01010a486df1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e732c227-c8f3-44fd-8d80-01010a486df1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Food Price.csv to Food Price (1).csv
#         date   Year                cmname        unit            category  \
# 0      #date  #year            #item+name  #item+unit          #item+type
# 1  1/15/2004   2004  Wheat flour - Retail          KG  cereals and tubers
# 2  2/15/2004   2004  Wheat flour - Retail          KG  cereals and tubers
# 3  3/15/2004   2004  Wheat flour - Retail          KG  cereals and tubers
# 4  4/15/2004   2004  Wheat flour - Retail          KG  cereals and tubers
# 5  5/15/2004   2004  Wheat flour - Retail          KG  cereals and tubers
# 6  6/15/2004   2004  Wheat flour - Retail          KG  cereals and tubers
# 7  7/15/2004   2004  Wheat flour - Retail          KG  cereals and tubers
# 8  8/15/2004   2004  Wheat flour - Retail          KG  cereals and tubers
# 9  9/15/2004   2004  Wheat flour - Retail          KG  cereals and tubers
#
#     price   currency        country      admname      adm1id       mktname  \
# 0  #value  #currency  #country+name   #adm1+name  #adm1+code  #name+market
# 1      13        PKR       Pakistan  Balochistan        2272        Quetta
# 2      13        PKR       Pakistan  Balochistan        2272        Quetta
# 3   14.25        PKR       Pakistan  Balochistan        2272        Quetta
# 4    12.5        PKR       Pakistan  Balochistan        2272        Quetta
# 5   13.25        PKR       Pakistan  Balochistan        2272        Quetta
# 6  13.405        PKR       Pakistan  Balochistan        2272        Quetta
# 7    13.6        PKR       Pakistan  Balochistan        2272        Quetta
# 8   13.75        PKR       Pakistan  Balochistan        2272        Quetta
# 9   13.75        PKR       Pakistan  Balochistan        2272        Quetta
#
#    mktid        cmid  ptid  umid            catid           sn  default
# 0    NaN  #item+code   NaN   NaN  #item+type+code     #meta+id      NaN
# 1  295.0          58  15.0   5.0                1  295_58_15_5      NaN
# 2  295.0          58  15.0   5.0                1  295_58_15_5      NaN
# 3  295.0          58  15.0   5.0                1  295_58_15_5      NaN
# 4  295.0          58  15.0   5.0                1  295_58_15_5      NaN
# 5  295.0          58  15.0   5.0                1  295_58_15_5      NaN
# 6  295.0          58  15.0   5.0                1  295_58_15_5      NaN
# 7  295.0          58  15.0   5.0                1  295_58_15_5      NaN
# 8  295.0          58  15.0   5.0                1  295_58_15_5      NaN
# 9  295.0          58  15.0   5.0                1  295_58_15_5      NaN

# %%
unwanted_column = df.drop(columns=['adm1id', 'mktid', 'ptid', 'umid', 'catid','sn','default'])
unwanted_rows = unwanted_column.drop(index=0)

# %%
unwanted_rows.tail(10)
# Out:
#             date  Year                                             cmname  \
# 7653   1/15/2019  2019  Wage (non-qualified labour, non-agricultural) ...
# 7654   2/15/2019  2019  Wage (non-qualified labour, non-agricultural) ...
# 7655   3/15/2019  2019  Wage (non-qualified labour, non-agricultural) ...
# 7656   4/15/2019  2019  Wage (non-qualified labour, non-agricultural) ...
# 7657   5/15/2019  2019  Wage (non-qualified labour, non-agricultural) ...
# 7658   6/15/2019  2019  Wage (non-qualified labour, non-agricultural) ...
# 7659   7/15/2019  2019  Wage (non-qualified labour, non-agricultural) ...
# 7660   8/15/2019  2019  Wage (non-qualified labour, non-agricultural) ...
# 7661   9/15/2019  2019  Wage (non-qualified labour, non-agricultural) ...
# 7662  10/15/2019  2019  Wage (non-qualified labour, non-agricultural) ...
#
#      unit  category   price currency   country admname  mktname cmid
# 7653  Day  non-food     935      PKR  Pakistan   Sindh  Karachi  465
# 7654  Day  non-food     935      PKR  Pakistan   Sindh  Karachi  465
# 7655  Day  non-food     935      PKR  Pakistan   Sindh  Karachi  465
# 7656  Day  non-food  936.75      PKR  Pakistan   Sindh  Karachi  465
# 7657  Day  non-food   978.2      PKR  Pakistan   Sindh  Karachi  465
# 7658  Day  non-food     988      PKR  Pakistan   Sindh  Karachi  465
# 7659  Day  non-food     988      PKR  Pakistan   Sindh  Karachi  465
# 7660  Day  non-food     988      PKR  Pakistan   Sindh  Karachi  465
# 7661  Day  non-food     984      PKR  Pakistan   Sindh  Karachi  465
# 7662  Day  non-food     994      PKR  Pakistan   Sindh  Karachi  465

# %%
df.describe()
# Out:
#              mktid    ptid         umid  default
# count  7662.000000  7662.0  7662.000000      0.0
# mean    292.975333    15.0     9.745236      NaN
# std       1.404504     0.0    10.767328      NaN
# min     291.000000    15.0     5.000000      NaN
# 25%     292.000000    15.0     5.000000      NaN
# 50%     293.000000    15.0     5.000000      NaN
# 75%     294.000000    15.0     5.000000      NaN
# max     295.000000    15.0    51.000000      NaN

# %%
unwanted_rows.notnull()
# Out:
#       date  Year  cmname  unit  category  price  currency  country  admname  \
# 1     True  True    True  True      True   True      True     True     True
# 2     True  True    True  True      True   True      True     True     True
# 3     True  True    True  True      True   True      True     True     True
# 4     True  True    True  True      True   True      True     True     True
# 5     True  True    True  True      True   True      True     True     True
# ...    ...   ...     ...   ...       ...    ...       ...      ...      ...
# 7658  True  True    True  True      True   True      True     True     True
# 7659  True  True    True  True      True   True      True     True     True
# 7660  True  True    True  True      True   True      True     True     True
# 7661  True  True    True  True      True   True      True     True     True
# 7662  True  True    True  True      True   True      True     True     True
#
#       mktname  cmid
# 1        True  True
# 2        True  True
# 3        True  True
# 4        True  True
# 5        True  True
# ...       ...   ...
# 7658     True  True
# 7659     True  True
# 7660     True  True
# 7661     True  True
# 7662     True  True
#
# [7662 rows x 11 columns]

# %%
unwanted_rows.isnull().sum().sum()
# Out:
# 0

# %%
df.corr()
# Out:
#            mktid  ptid     umid  default
# mktid    1.00000   NaN  0.01185      NaN
# ptid         NaN   NaN      NaN      NaN
# umid     0.01185   NaN  1.00000      NaN
# default      NaN   NaN      NaN      NaN

# %%
unwanted_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7662 entries, 1 to 7662
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      7662 non-null   object
#  1   Year      7662 non-null   object
#  2   cmname    7662 non-null   object
#  3   unit      7662 non-null   object
#  4   category  7662 non-null   object
#  5   price     7662 non-null   object
#  6   currency  7662 non-null   object
#  7   country   7662 non-null   object
#  8   admname   7662 non-null   object
#  9   mktname   7662 non-null   object
#  10  cmid      7662 non-null   object
# dtypes: object(11)
# memory usage: 718.3+ KB

# %%
unwanted_rows.nunique()
# Out:
# date         190
# Year          16
# cmname        17
# unit           4
# category       7
# price       2988
# currency       1
# country        1
# admname        4
# mktname        5
# cmid          17
# dtype: int64

# %%
print(unwanted_rows.duplicated())
# Out:
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 7658    False
# 7659    False
# 7660    False
# 7661    False
# 7662    False
# Length: 7662, dtype: bool

# %%
unwanted_rows.iloc[:50, 1:41]
# Out:
#     Year                cmname unit            category    price currency  \
# 1   2004  Wheat flour - Retail   KG  cereals and tubers       13      PKR
# 2   2004  Wheat flour - Retail   KG  cereals and tubers       13      PKR
# 3   2004  Wheat flour - Retail   KG  cereals and tubers    14.25      PKR
# 4   2004  Wheat flour - Retail   KG  cereals and tubers     12.5      PKR
# 5   2004  Wheat flour - Retail   KG  cereals and tubers    13.25      PKR
15/2019  2019  Wage (non-qualified labour, non-agricultural) ...
# 7659   7/15/2019  2019  Wage (non-qualified labour, non-agricultural) ...
# 7660   8/15/2019  2019  Wage (non-qualified labour, non-agricultural) ...
# 7661   9/15/2019  2019  Wage (non-qualified labour, non-agricultural) ...
# 7662  10/15/2019  2019  Wage (non-qualified labour, non-agricultural) ...
#
#      unit            category  price currency   country      admname  mktname  \
# 1      KG  cereals and tubers     13      PKR  Pakistan  Balochistan   Quetta
# 2      KG  cereals and tubers     13      PKR  Pakistan  Balochistan   Quetta
# 3      KG  cereals and tubers  14.25      PKR  Pakistan  Balochistan   Quetta
# 4      KG  cereals and tubers   12.5      PKR  Pakistan  Balochistan   Quetta
# 5      KG  cereals and tubers  13.25      PKR  Pakistan  Balochistan   Quetta
# ...   ...                 ...    ...      ...       ...          ...      ...
# 7658  Day            non-food    988      PKR  Pakistan        Sindh  Karachi
# 7659  Day            non-food    988      PKR  Pakistan        Sindh  Karachi
# 7660  Day            non-food    988      PKR  Pakistan        Sindh  Karachi
# 7661  Day            non-food    984      PKR  Pakistan        Sindh  Karachi
# 7662  Day            non-food    994      PKR  Pakistan        Sindh  Karachi
#
#      cmid
# 1      58
# 2      58
# 3      58
# 4      58
# 5      58
# ...   ...
# 7658  465
# 7659  465
# 7660  465
# 7661  465
# 7662  465
#
# [7662 rows x 11 columns]

# %%
unwanted_rows.sample(n = 200)
# Out:
#             date  Year                           cmname unit  \
# 4181   9/15/2017  2017                 Poultry - Retail   KG
# 6653   6/15/2019  2019           Oil (cooking) - Retail    L
# 5122   3/15/2007  2007                   Wheat - Retail   KG
# 2300  12/15/2018  2018                   Sugar - Retail   KG
# 6041   5/15/2019  2019             Beans(mash) - Retail   KG
# ...          ...   ...                              ...  ...
# 1237   3/15/2017  2017  Fuel (petrol-gasoline) - Retail    L
# 3112   8/15/2012  2012             Wheat flour - Retail   KG
# 2936  12/15/2018  2018             Beans(mash) - Retail   KG
# 3615  10/15/2010  2010                   Wheat - Retail   KG
# 216    2/15/2008  2008           Rice (coarse) - Retail   KG
#
#                  category   price currency   country             admname  \
# 4181  meat, fish and eggs    94.5      PKR  Pakistan              Punjab
# 6653         oil and fats     218      PKR  Pakistan               Sindh
# 5122   cereals and tubers    11.7      PKR  Pakistan              Punjab
# 2300   miscellaneous food   56.83      PKR  Pakistan  Khyber Pakhtunkhwa
# 6041      pulses and nuts  155.83      PKR  Pakistan              Punjab
# ...                   ...     ...      ...       ...                 ...
# 1237             non-food   73.38      PKR  Pakistan         Balochistan
# 3112   cereals and tubers   31.46      PKR  Pakistan              Punjab
# 2936      pulses and nuts     135      PKR  Pakistan  Khyber Pakhtunkhwa
# 3615   cereals and tubers   26.31      PKR  Pakistan              Punjab
# 216    cereals and tubers      23      PKR  Pakistan         Balochistan
#
#        mktname cmid
# 4181    Lahore  138
# 6653   Karachi   82
# 5122    Multan   84
# 2300  Peshawar   97
# 6041    Multan  326
# ...        ...  ...
# 1237    Quetta  285
# 3112    Lahore   58
# 2936  Peshawar  326
# 3615    Lahore   84
# 216     Quetta   60
#
# [200 rows x 11 columns]

# %%
unwanted_rows.sample(frac = 1)
# Out:
#            date  Year                           cmname unit  \
# 6762  9/15/2014  2014                   Wheat - Retail   KG
# 4235  4/15/2017  2017                    Salt - Retail   KG
# 6506  2/15/2018  2018         Lentils (masur) - Retail   KG
# 6304  6/15/2006  2006           Rice (coarse) - Retail   KG
# 3513  2/15/2016  2016           Oil (cooking) - Retail    L
# ...         ...   ...                              ...  ...
# 5930  7/15/2015  2015         Lentils (moong) - Retail   KG
# 851   9/15/2005  2005  Rice (basmati, broken) - Retail   KG
# 2493  9/15/2012  2012  Rice (basmati, broken) - Retail   KG
# 4186  2/15/2018  2018                 Poultry - Retail   KG
# 5204  1/15/2014  2014                   Wheat - Retail   KG
#
#                  category   price currency   country             admname  \
# 6762   cereals and tubers      34      PKR  Pakistan               Sindh
# 4235   miscellaneous food      10      PKR  Pakistan              Punjab
# 6506      pulses and nuts  107.89      PKR  Pakistan               Sindh
# 6304   cereals and tubers    15.5      PKR  Pakistan               Sindh
# 3513         oil and fats     186      PKR  Pakistan              Punjab
# ...                   ...     ...      ...       ...                 ...
# 5930      pulses and nuts   147.5      PKR  Pakistan              Punjab
# 851    cereals and tubers   22.38      PKR  Pakistan         Balochistan
# 2493   cereals and tubers      75      PKR  Pakistan  Khyber Pakhtunkhwa
# 4186  meat, fish and eggs     150      PKR  Pakistan              Punjab
# 5204   cereals and tubers   37.75      PKR  Pakistan              Punjab
#
#        mktname cmid
# 6762   Karachi   84
# 4235    Lahore  185
# 6506   Karachi   61
# 6304   Karachi   60
# 3513    Lahore   82
# ...        ...  ...
# 5930    Multan  325
# 851     Quetta  122
# 2493  Peshawar  122
# 4186    Lahore  138
# 5204    Multan   84
#
# [7662 rows x 11 columns]

# %%
Wheat_flour = unwanted_rows[unwanted_rows.cmid == "58"]
Rice_coarse = unwanted_rows[unwanted_rows.cmid == "60"]
Lentils_masur = unwanted_rows[unwanted_rows.cmid == "61"]
Milk = unwanted_rows[unwanted_rows.cmid == "81"]
Oil = unwanted_rows[unwanted_rows.cmid == "82"]
Wheat = unwanted_rows[unwanted_rows.cmid == "84"]
Eggs = unwanted_rows[unwanted_rows.cmid == "92"]
Sugar = unwanted_rows[unwanted_rows.cmid == "97"]
Ghee = unwanted_rows[unwanted_rows.cmid == "106"]
Rice_basmati = unwanted_rows[unwanted_rows.cmid == "122"]
Poultry = unwanted_rows[unwanted_rows.cmid == "138"]
Salt = unwanted_rows[unwanted_rows.cmid == "185"]
Fuel_diesel = unwanted_rows[unwanted_rows.cmid == "284"]
Fuel_petrol = unwanted_rows[unwanted_rows.cmid == "285"]
Lentils_mong = unwanted_rows[unwanted_rows.cmid == "325"]
Beans = unwanted_rows[unwanted_rows.cmid == "326"]
Wage = unwanted_rows[unwanted_rows.cmid == "465"]

# %%
Wheat_flour
fig = plt.figure()
ax = fig.add_axes([1,1,2,2])
ax.bar(Wheat_flour.Year,Wheat_flour.price)
plt.show()
